# %%
import pandas as pd

# %%
# %ls
# Out:
# Untitled.ipynb  not_found.txt   results.csv     wordlist.csv

# %%
pd.read_csv("results.csv")[22:30]
# Out:
#     Frequency  Lemma             Grammatical Function Homograph Number  \
# 22          7     la                     pr. pers. f.               II
# 23          7     la                       n. m. inv.              III
# 24         18    les                              NaN              NaN
# 25         17  faire  v. tr., intr., impers. et pron.              NaN
# 26         16     ça                       pron. dém.              NaN
# 27         15  aller                         v. intr.                I
# 28         15  aller                            n. m.               II
# 29         10   vous                        pr. pers.              NaN
#
#                                        Definition URL  \
# 22  https://www.dictionnaire-academie.fr/article/A...
# 23  https://www.dictionnaire-academie.fr/article/A...
# 24  https://www.dictionnaire-academie.fr/article/A...
# 25  https://www.dictionnaire-academie.fr/article/A...
# ...
